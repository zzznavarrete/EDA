# %% [markdown]
# # EDA
# ### Exploratory Data Analisys
#
#
# ### Introducción
# El inicio de cualquier modelo de ML es a través de la exploración.
# Es un análisis exploratorio,<b>tú no sabes lo que es lo que quieres ver,</b> estás entendiendo lo que tienes.
#
# ### Terminologías
# KDD: Knowledge Discovery in Database
#
# SEMMA: Sample, Explore, Modify, Model and Assess.
#
# __(actual)__ CRIPST-DM: Cross Industry Standard Process for Data Mining.
#
# ### Dentro de CRIPST-DM tenemos las etapas de:
# - Communication.
#
# - Data requirements.
#
# - Data collection.
#
# - Data processing.
#
# - Data product.
#
# - Data cleaning.
#
# - EDA.
#
# - Modeling and algortihm.
#
#
# ## EDA
# Después de pasar por toda una serie de ingeniería de datos, en donde ya tenemos nuestro dataset previamente pre procesado, y en formato tabular procedemos a nuestro análisis exploratorio.
#
# El EDA tiene diferentes etapas:
#
# - Definición del problema (Business problem).
#
# - Preparación de los datos.
#
# - Análisis de datos.
#
# - Desarrollo y representasitión de los resultados.
#
#
#
# Es muy importante resaltar la importancia de tener un **porque** a la hora de emprender la tarea de crear un modelo de machine learning, debe haber una definición del problema o del desafío a solucionar, para ayudarnos a contextualizarnos en función de los datos disponibles existe EDA.
#
#
# ---
#
#
# ## Diferencias de EDA y otros análisis
#
# - Análisis clásico (ej Excel): Aquí simplemente mostramos los resultados, no importa que pase con esa información, no importa que es lo que significa o que hubo antes como tal, solo se presenta un análisis clásico, un análisis de medias, un análisis estadístico, pero no se da un contexto de un problema que vayamos a resolver, sólo facts estadísticos.
#
# - Análisis bayesiano: Siempre considera que es la distribución a priori, es decir que es lo que paso anteriormente para yo predecir el futuro, pero aveces no toma en consideración que es lo que puede pasar con este modelo, que mas podemos entender y que otro tipo de variables podemos meter.
#
# - EDA: Este es totalmente dinámico, puede regresar para entender lo que está pasando y al final lanzar un modelo de ML, DP, alguna automatización o alguna mejora para el negocio que le dé una ganancia, por eso es muy importante para entender que el EDA, parte del contexto del negocio, parte de una serie de hipótesis para hacer un análisis dinámico para entender que valor y que propuesta voy a dar.
#
# <img src="img/eda-comparativa.png" alt="drawing" width="800"/>
